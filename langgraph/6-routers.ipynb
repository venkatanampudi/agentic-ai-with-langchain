# %% [markdown]
# ### Routers
#
# #### RECAP:
# * 1. Graph that uses messages as a state and chat model with bound tools
#
# #### Graph: Graph will do
# * 1. Return a tool call (inside tool call there is a function we can define), hence LLM call this tool
# * 2. Natural Language Response

# %% [markdown]
# ### Router Definition in Agentic AI:
# ##### In Agentic AI, a router is a decision-making component that directs a task, message, or request to the right agent, tool, or workflow based on intent, context, or rules.Think of it like a traffic controller for agents
#
# #### Why routers are important in Agentic AI ?
#
# Agentic systems usually have:
#
# Multiple agents (planner, coder, researcher, security agent, etc.)
#
# Multiple tools (search, database, APIs, scanners)
#
# Multiple paths (retry, escalate, summarize, handoff)
#
# Without a router, everything goes to one agent → inefficient and brittle.
#
# In a simple agent graph where the chat model routes between a direct response or a tool call based upon the user input. In a simple agent graph, where the LLM is directing the control flow either by calling a tool or just responding directly.

# %% [markdown]
# ![Alt text](llm_router.png)

# %% [markdown]
# ### Basic Agent:
# ##### when we ask something to LLM, LLM respond with natural language response or call a tool if there is a tool(s) binded to it. Next LLM may call another step or other step and go to end.
# ![Alt text](basic_agent.png)
