# %% [markdown]
# ### How to split by HTML Header
# ##### HTMLHeaderTextSplitter is a "structure-aware" chunker that splits text at the HTML element level and adds metadata for each header "relevant" to any given chunk. It can return chunks element by element or combine elements with the same metadata, with the objectives of:
# * (a) keeping related text grouped (more or less) sematically & syntactically and,
# * (b) preserving context-rich information encoded in document strucutres.
# ##### It can be used with other text splitters as part of a chunking pipeline.

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter

### This HTML string got it from chatgpt

html_string="""
<header>
  <h1>My Website Header 1</h1>
    <h2>My Website Header 2</h2>
</header>
"""

headers_to_split_on=[("h1","Header 1"),("h2","Header 2")]

html_splitter=HTMLHeaderTextSplitter(headers_to_split_on)
html_header_splits=html_splitter.split_text(html_string)
html_header_splits
# Out:
# [Document(metadata={'Header 1': 'My Website Header 1'}, page_content='My Website Header 1'),
#  Document(metadata={'Header 1': 'My Website Header 1', 'Header 2': 'My Website Header 2'}, page_content='My Website Header 2')]

# %%
### HTMLHeaderTextSplitter for a URL


from bs4 import MarkupResemblesLocatorWarning 
import warnings
from langchain_text_splitters import HTMLHeaderTextSplitter

url="https://plato.stanford.edu/entries/goedel/"

headers_to_split_on=[
    ("h1","Header 1"),
    ("h2","Header 2"),
    ("h3","Header 3"),
    ("h4","Header 4")
]

html_splitter=HTMLHeaderTextSplitter(headers_to_split_on)
html_header_splits=html_splitter.split_text(url)
html_header_splits
# Out:
# [Document(metadata={}, page_content='https://plato.stanford.edu/entries/goedel/')]
