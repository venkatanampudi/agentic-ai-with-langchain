# %% [markdown]
# ![image.png](attachment:image.png)
#
# 1️⃣ 𝗧𝗿𝗮𝗱𝗶𝘁𝗶𝗼𝗻𝗮𝗹 𝗔𝗜 - 𝗙𝗶𝘅𝗲𝗱 𝗜𝗻𝘁𝗲𝗹𝗹𝗶𝗴𝗲𝗻𝗰𝗲
# This is the classic approach. A fixed pipeline.
# You give it a task. You give it data. You train it.
# It's great at one specific thing, like spotting fraud. But it's stuck in time.
#
# It only knows what you taught it.
# Can't learn new things on its own.
# When the world changes, the model fails.
#
# 2️⃣ 𝗔𝗴𝗲𝗻𝘁𝗶𝗰 𝗔𝗜 - 𝗚𝗼𝗮𝗹-𝗗𝗿𝗶𝘃𝗲𝗻 𝗦𝘆𝘀𝘁𝗲𝗺𝘀
#
# This is a big change. It focuses on goals, not tasks.
# You don't tell it how. You tell it what you want.
# The AI thinks for itself. It plans steps.
# It uses tools like search or email to get the job done.
# It doesn’t wait for you. It plans, acts, and checks its own work.
# But without grounded data, it can hallucinate.
#
# 3️⃣ 𝗔𝗴𝗲𝗻𝘁𝗶𝗰 𝗥𝗔𝗚 - 𝗜𝗻𝘁𝗲𝗹𝗹𝗶𝗴𝗲𝗻𝗰𝗲 𝗪𝗶𝘁𝗵 𝗠𝗲𝗺𝗼𝗿𝘆
#
# RAG (Retrieval-Augmented Generation) connects AI to your live company data.
# It combines agency + memory.
# Fetches live data, reasons through it, acts, and writes outcomes back to long-term memory.
#
# It adapts. Doesn't just execute. Gets smarter with every loop.
#
#
# 𝗧𝗵𝗲 𝗿𝗲𝗮𝗹 𝘀𝗵𝗶𝗳𝘁? 𝗖𝗼𝗺𝗯𝗶𝗻𝗶𝗻𝗴 𝗮𝗹𝗹 𝘁𝗵𝗿𝗲𝗲.
#
# Modern systems retrieve data, reason over it, take action, and log everything.
# Predictive, grounded, and autonomous.
#
# 𝗧𝗿𝗮𝗱𝗶𝘁𝗶𝗼𝗻𝗮𝗹 𝗔𝗜 → learns from the past
# 𝗔𝗴𝗲𝗻𝘁𝗶𝗰 𝗔𝗜 → acts and evolves in real time
# 𝗥𝗔𝗚 → grounds answers in facts
